# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b433facb-2599-4482-9b98-e45d44bb2f72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b433facb-2599-4482-9b98-e45d44bb2f72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
df = pd.read_csv('/content/BloodPressure - BloodPressure.csv')
df
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
df[['bp_before', 'bp_after']].describe()
# Out:
#         bp_before    bp_after
# count  120.000000  120.000000
# mean   156.450000  151.358333
# std     11.389845   14.177622
# min    138.000000  125.000000
# 25%    147.000000  140.750000
# 50%    154.500000  149.500000
# 75%    164.000000  161.000000
# max    185.000000  185.000000

# %%
significance = 0.01
stat,p_value = stats.ttest_rel(df['bp_before'], df['bp_after'])

print('t_stat: %0.5f, p_value: %0.4f' % (stat, p_value))
if p_value < significance:
  print ("Reject the null hypothesis")
else:
  print ("Accpet the null hypothesis")
# Out:
# t_stat: 3.33719, p_value: 0.0011
# Reject the null hypothesis

# %%
df.loc[df['sex'] == 'Male'].describe()
# Out:
#          patient   bp_before    bp_after
# count  60.000000   60.000000   60.000000
# mean   30.500000  159.266667  155.516667
# std    17.464249   11.413442   15.243217
# min     1.000000  140.000000  125.000000
# 25%    15.750000  150.750000  145.000000
# 50%    30.500000  158.000000  158.500000
# 75%    45.250000  170.000000  164.750000
# max    60.000000  185.000000  185.000000

# %%
df.loc[df['sex'] == 'Female'].describe()
# Out:
#           patient   bp_before    bp_after
# count   60.000000   60.000000   60.000000
# mean    90.500000  153.633333  147.200000
# std     17.464249   10.735600   11.742722
# min     61.000000  138.000000  127.000000
# 25%     75.750000  144.750000  138.000000
# 50%     90.500000  151.000000  146.000000
# 75%    105.250000  161.250000  152.000000
# max    120.000000  185.000000  178.000000

# %%
significance = 0.05
stat,p_value = stats.ttest_rel(df.loc[df['sex'] == 'Male']['bp_before'], df.loc[df['sex'] == 'Male']['bp_after'])

print('t_stat: %0.5f, p_value: %0.4f' % (stat, p_value))
if p_value < significance:
  print ("Reject the null hypothesis")
else:
  print ("Accpet the null hypothesis")
# Out:
# t_stat: 1.54314, p_value: 0.1281
# Accpet the null hypothesis

# %%
stat,p_value = stats.ttest_rel(df.loc[df['sex'] == 'Female']['bp_before'], df.loc[df['sex'] == 'Female']['bp_after'])

print('t_stat: %0.5f, p_value: %0.4f' % (stat, p_value))
if p_value < significance:
  print ("Reject the null hypothesis")
else:
  print ("Accpet the null hypothesis")
# Out:
# t_stat: 3.47675, p_value: 0.0010
# Reject the null hypothesis
